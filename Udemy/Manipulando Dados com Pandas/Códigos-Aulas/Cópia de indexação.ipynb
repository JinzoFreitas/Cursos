# %%
# Meus outros cursos: https://linktr.ee/rafaelfvcs

# %%
import numpy as np

# %%
v = [22, 55, 7, 9]

# %%
v
# Out:
# [22, 55, 7, 9]

# %%
v[2]
# Out:
# 7

# %%
v[0]
# Out:
# 22

# %%
v[-1]
# Out:
# 9

# %%
v
# Out:
# [22, 55, 7, 9]

# %%
v[-5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-7b3f7247ac50> in <module>()
# ----> 1 v[-5]
#
# IndexError: list index out of range
