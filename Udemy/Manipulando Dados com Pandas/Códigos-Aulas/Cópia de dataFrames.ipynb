# %%
# Meus outros cursos: https://linktr.ee/rafaelfvcs

# %%
import pandas as pd
import numpy as np

# %%
series = pd.Series([7, 4,2, np.nan,6,9 ])

# %%
series
# Out:
# 0    7.0
# 1    4.0
# 2    2.0
# 3    NaN
# 4    6.0
# 5    9.0
# dtype: float64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
datas = pd.date_range('20180101', periods = 6, freq="D")

# %%
datas
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
type(datas)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df = pd.DataFrame(np.random.randn(6,4), index = datas, columns = list("ABCD")) # list("ABCD")

# %%
df
# Out:
#                    A         B         C         D
# 2018-01-01  1.687570 -0.053879 -0.705973 -1.275664
# 2018-01-02 -0.393480 -0.646968  0.271080  0.525474
# 2018-01-03  0.669348 -0.179501 -0.009268  0.453886
# 2018-01-04 -0.288417  1.123031  0.218640  0.371278
# 2018-01-05 -0.345182  0.735818  1.023152  0.790538
# 2018-01-06 -0.954270  0.474676 -1.091628  1.366616

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df2 = pd.DataFrame({"A":7, 
                   'B': pd.Timestamp('20190101'),
                   'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                   "D": np.array([3] * 4, dtype='int32'),
                   "E": pd.Categorical(["test", "train", "test", "train"]),
                   'F':'Python'})

# %%
df2
# Out:
#    A          B    C  D      E       F
# 0  7 2019-01-01  1.0  3   test  Python
# 1  7 2019-01-01  1.0  3  train  Python
# 2  7 2019-01-01  1.0  3   test  Python
# 3  7 2019-01-01  1.0  3  train  Python

# %%
df2.dtypes
# Out:
# A             int64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df
# Out:
#                    A         B         C         D
# 2018-01-01  1.687570 -0.053879 -0.705973 -1.275664
# 2018-01-02 -0.393480 -0.646968  0.271080  0.525474
# 2018-01-03  0.669348 -0.179501 -0.009268  0.453886
# 2018-01-04 -0.288417  1.123031  0.218640  0.371278
# 2018-01-05 -0.345182  0.735818  1.023152  0.790538
# 2018-01-06 -0.954270  0.474676 -1.091628  1.366616

# %%
df2
# Out:
#    A          B    C  D      E       F
# 0  7 2019-01-01  1.0  3   test  Python
# 1  7 2019-01-01  1.0  3  train  Python
# 2  7 2019-01-01  1.0  3   test  Python
# 3  7 2019-01-01  1.0  3  train  Python

# %%
# Visualizar dados

# %%
df.head(2)
# Out:
#                   A         B         C         D
# 2018-01-01  1.68757 -0.053879 -0.705973 -1.275664
# 2018-01-02 -0.39348 -0.646968  0.271080  0.525474

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2018-01-04 -0.288417  1.123031  0.218640  0.371278
# 2018-01-05 -0.345182  0.735818  1.023152  0.790538
# 2018-01-06 -0.954270  0.474676 -1.091628  1.366616

# %%
df.index
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
c = df.columns

# %%
c
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df
# Out:
#                    A         B         C         D
# 2018-01-01  1.687570 -0.053879 -0.705973 -1.275664
# 2018-01-02 -0.393480 -0.646968  0.271080  0.525474
# 2018-01-03  0.669348 -0.179501 -0.009268  0.453886
# 2018-01-04 -0.288417  1.123031  0.218640  0.371278
# 2018-01-05 -0.345182  0.735818  1.023152  0.790538
# 2018-01-06 -0.954270  0.474676 -1.091628  1.366616

# %%
df.to_numpy()
# Out:
# array([[ 1.68757043, -0.05387942, -0.70597287, -1.27566418],
#        [-0.39348005, -0.64696825,  0.27108038,  0.52547382],
#        [ 0.66934798, -0.17950054, -0.00926847,  0.45388644],
#        [-0.28841737,  1.12303119,  0.21864005,  0.37127826],
#        [-0.34518215,  0.73581771,  1.0231518 ,  0.79053794],
#        [-0.95426968,  0.47467583, -1.09162792,  1.36661566]])

# %%
df.T
# Out:
#    2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05  2018-01-06
# A    1.687570   -0.393480    0.669348   -0.288417   -0.345182   -0.954270
# B   -0.053879   -0.646968   -0.179501    1.123031    0.735818    0.474676
# C   -0.705973    0.271080   -0.009268    0.218640    1.023152   -1.091628
# D   -1.275664    0.525474    0.453886    0.371278    0.790538    1.366616

# %%
df2.T
# Out:
#                      0  ...                    3
# A                    7  ...                    7
# B  2019-01-01 00:00:00  ...  2019-01-01 00:00:00
# C                    1  ...                    1
# D                    3  ...                    3
# E                 test  ...                train
# F               Python  ...               Python
#
# [6 rows x 4 columns]

# %%
df2.to_numpy()
# Out:
# array([[7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'test', 'Python'],
#        [7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'train', 'Python'],
#        [7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'test', 'Python'],
#        [7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'train', 'Python']],
#       dtype=object)
