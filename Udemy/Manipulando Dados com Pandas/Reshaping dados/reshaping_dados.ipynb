# %%
# Meus outros cursos: https://linktr.ee/rafaelfvcs

# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range('20200101', periods=6)

df = pd.DataFrame(np.random.randn(6, 4), index=datas, columns=['Var_A', 'Var_B', 'Var_C', 'Var_D'])

# %%
df

# %%
dft = df.T

# %%
dft

# %%
df.shape

# %%
dft.shape
# Out:
# (4, 6)

# %%
np.size(dft.values)

# %%
dft.values
# Out:
# array([[ 0.04786754,  0.91023237,  0.70185798,  0.49180582,  0.08817627,
#         -0.49033328],
#        [ 1.15986589, -0.35682936, -1.75479227,  0.59579423,  0.86959704,
#          0.88318227],
#        [ 0.27802034,  0.89274217,  0.24200031, -0.28241745,  1.98673972,
#         -0.47214166],
#        [-1.58553729,  0.51520525, -1.42304052, -0.08102234, -0.92097384,
#          0.96847602]])

# %%
v = dft.values

# %%
v.reshape((3,12))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-317-a80c3c55fbc0> in <module>()
# ----> 1 v.reshape((3,12))
#
# ValueError: cannot reshape array of size 24 into shape (3,12)
