# %%
# Meus outros cursos: https://linktr.ee/rafaelfvcs

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.style.available

# %%
plt.style.use()

# %%
plt.rcParams['figure.figsize'] = (15,7)

# %%
d = pd.read_csv('titanic_train.csv')

# %%
d.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
d.shape
# Out:
# (891, 12)

# %%
plt.plot( d.Age , '*-r')
plt.title('Informações dos passaeiros do Titanic')
plt.xlabel('Passageiro', size=18)
plt.ylabel('Idade', size=18)
plt.show()

# %%
d.Age.plot()
plt.xlabel('Passageiro', size=18)
plt.ylabel('Idade', size=18)
plt.show()

# %%
d.plot()
plt.show()

# %%
# Scatter plot

# %%
d.head(2)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
#
# [2 rows x 12 columns]

# %%
plt.scatter(d.PassengerId, d.Age, color='blue', marker='>')
plt.show()

# %%
# Histogramas

# %%
d.head(3)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
#
# [3 rows x 12 columns]

# %%
d.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
d.Age.hist()
plt.xlabel('idade')
plt.ylabel('Frequência Observada')
plt.savefig('nome_fig2.png', transparent=True)
plt.show()
